# %% [markdown]
# ### Objective: Learn Python basics and perform basic data exploration and cleaning using Pandas. Steps: 1.Load a CSV dataset into a Pandas DataFrame. 2.Explore data (head/tail, shape, columns, data types). 3.Handle missing values (identify, fill/drop). 4.Perform basic operations (filter rows, select columns). 5.Remove duplicates. 6.Create a derived column (total_amount = price * quantity). 7.Save the cleaned dataset as a new CSV file. Output: Jupyter Notebook (.ipynb) + cleaned CSV + brief summary.

# %% [markdown]
# ### 1.Loading a csv file

# %%
import pandas as pd
df= pd.read_csv("C:\\praveen\\Datasets\\Combined_dataset.csv")
df

# %% [markdown]
# ### 2.Explore Data

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.columns

# %%
df.info

# %%
df["seller_name"].dtype

# %%
df.dtypes

# %% [markdown]
# ### 3.Handling Missing Values

# %%
df.isnull().sum()

# %%
df1=df.dropna()
df1

# %%
print(df1.head())

# %%
df1.isnull().sum()

# %% [markdown]
# ### 4.basic operations (filter rows, select columns)

# %%
df[df["rating"]>4.2]

# %%
df[["product_id","title","rating","final_price","seller_name","category"]]

# %% [markdown]
# ### 5.Remove Duplicates

# %%
df1=df1.drop_duplicates()

# %%
df1

# %%
df1.duplicated().sum()

# %% [markdown]
# ### 6.derived column (total_amount = price * quantity),(quantity column not given in dataset)

# %%
df1["quantity"]=1 
df1["total_amount"]=df1["final_price"]*df1["quantity"]

# %%
df1

# %% [markdown]
# ### 7.saving the clean dataset

# %%
df1.to_csv("cleaned_shopping.csv",index=False)
